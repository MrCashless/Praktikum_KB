# %% [markdown]
# # 𝐁𝐑𝐀𝐌𝐀𝐍𝐓𝐘𝐎 𝐀𝐑𝐃𝐈 𝐇𝐀𝐑𝐈𝐌𝐔𝐓𝐈 𝐖𝐈𝐁𝐈𝐒𝐎𝐍𝐎
# ## NIM: 2109106013
# ## POSTTEST 2 KECERDASAN BUATAN

# %% [markdown]
# ### Import Library yang akan digunakan

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Membaca data file CSV

# %%
df = pd.read_csv("FIFA_data.csv")

# %% [markdown]
# ### Mengetahui informasi dari isi data file CSV

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18206 entries, 0 to 18205
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18206 non-null  int64
#  1   ID                        18206 non-null  int64
#  2   Name                      18206 non-null  object
#  3   Age                       18206 non-null  int64
#  4   Photo                     18206 non-null  object
#  5   Nationality               18206 non-null  object
#  6   Flag                      18206 non-null  object
#  7   Overall                   18206 non-null  int64
#  8   Potential                 18206 non-null  int64
#  9   Club                      17965 non-null  object
#  10  Club Logo                 18206 non-null  object
#  11  Value                     18206 non-null  object
#  12  Wage                      18206 non-null  object
# ...

# %% [markdown]
# ### Mengimpor data file CSV ke dalam Dictionary

# %%
df_show = {
'atribut': [],
'atribut_objek': 0,
'atribut_nomor': 0,
'atribut_null': 0,
'jml_record': 0,
}

# %%
df_show['atribut'] = list(df.columns.values)
df_show['atribut_objek'] = list(df.select_dtypes(['object']).columns)
df_show['atribut_nomor'] = list(df.select_dtypes(['int64','float64']).columns)
df_show['atribut_null'] = list(df.loc[:, df.isnull().any()].columns)
df_show['jml_record'] = df.shape[0]

# %% [markdown]
# ### Menampilkan Hasil dict df_show:

# %% [markdown]
# ### A) Jumlah Record Data

# %%
print("Jumlah Record Pada Data :", df_show['jml_record'])
# Out:
# Jumlah Record Pada Data : 18206

# %% [markdown]
# ### B) Nama Attributes Data

# %%
print("Nama Seluruh Atribut Data :", df_show['atribut'])
# Out:
# Nama Seluruh Atribut Data : ['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GK
# ...

# %% [markdown]
# ### C) Jumlah Attributes Data

# %%
print("Total Atribut Data :", len(df_show['atribut']))
print("Total Atribut Dengan Tipe Data Object :", len(df_show['atribut_objek']))
print("Total Atribut Dengan Tipe Data Angka :", len(df_show['atribut_nomor']))
print("Total Atribut Null :", len(df_show['atribut_null']))
# Out:
# Total Atribut Data : 89
# Total Atribut Dengan Tipe Data Object : 45
# Total Atribut Dengan Tipe Data Angka : 44
# Total Atribut Null : 76

# %% [markdown]
# ### Menampilkan rata-rata STD, Nilai Min, Max, Q1, Q2, Q3 dari attriibutes angka

# %%
df.describe()
# Out:
#        Unnamed: 0          ID        Age    Overall  Potential    Special  \
# count  18,206.000  18,206.000 18,206.000 18,206.000 18,206.000 18,206.000
# mean    9,102.500 214,296.583     25.123     66.240     71.308  1,597.825
# std     5,255.764  29,965.130      4.670      6.907      6.137    272.586
# min         0.000      16.000     16.000     47.000     48.000    731.000
# 25%     4,551.250 200,315.250     21.000     62.000     67.000  1,457.000
# 50%     9,102.500 221,757.500     25.000     66.000     71.000  1,635.000
# 75%    13,653.750 236,528.500     28.000     71.000     75.000  1,787.000
# max    18,205.000 246,620.000     45.000     94.000     95.000  2,346.000
#
#        International Reputation  Weak Foot  Skill Moves  Jersey Number  ...  \
# count                18,158.000 18,158.000   18,158.000     18,146.000  ...
# mean                      1.113      2.947        2.361         19.545  ...
# ...

# %% [markdown]
# ### Menampilkan Nilai Korelasi Attributes Angka

# %%
df.corr()
# Out:
#                           Unnamed: 0     ID    Age  Overall  Potential  \
# Unnamed: 0                     1.000  0.416 -0.455   -0.973     -0.633
# ID                             0.416  1.000 -0.739   -0.417      0.047
# Age                           -0.455 -0.739  1.000    0.452     -0.253
# Overall                       -0.973 -0.417  0.452    1.000      0.661
# Potential                     -0.633  0.047 -0.253    0.661      1.000
# Special                       -0.596 -0.231  0.237    0.607      0.384
# International Reputation      -0.413 -0.356  0.254    0.500      0.373
# Weak Foot                     -0.204 -0.076  0.060    0.212      0.162
# Skill Moves                   -0.416 -0.057  0.028    0.414      0.354
# Jersey Number                  0.214  0.182 -0.241   -0.219     -0.010
# Crossing                      -0.390 -0.132  0.131    0.395      0.246
# Finishing                     -0.326 -0.082  0.069    0.333      0.243
# ...

# %% [markdown]
# ### Mengubah Nilai Salah Satu Attributes Angka Menjadi Desimal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18206 entries, 0 to 18205
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18206 non-null  int64
#  1   ID                        18206 non-null  int64
#  2   Name                      18206 non-null  object
#  3   Age                       18206 non-null  int64
#  4   Photo                     18206 non-null  object
#  5   Nationality               18206 non-null  object
#  6   Flag                      18206 non-null  object
#  7   Overall                   18206 non-null  int64
#  8   Potential                 18206 non-null  int64
#  9   Club                      17965 non-null  object
#  10  Club Logo                 18206 non-null  object
#  11  Value                     18206 non-null  object
#  12  Wage                      18206 non-null  object
# ...

# %% [markdown]
# ### Pengubahan Attributes Special (int64) Menjadi Desimal

# %% [markdown]
# #### Attributes Special sebelum dikonversi ke desimal:

# %%
df[['Special']]
# Out:
#        Special
# 0         2202
# 1         2228
# 2         2143
# 3         1471
# 4         2281
# ...        ...
# 18201     1098
# 18202     1307
# 18203     1098
# 18204     1189
# 18205     1228
#
# [18206 rows x 1 columns]

# %% [markdown]
# #### Attributes Special sesudah dikonversi ke desimal:

# %%
df['Special'] = df['Special'].astype('float64')
pd.options.display.float_format = "{:,.3f}".format
df[['Special']]
# Out:
#         Special
# 0     2,202.000
# 1     2,228.000
# 2     2,143.000
# 3     1,471.000
# 4     2,281.000
# ...         ...
# 18201 1,098.000
# 18202 1,307.000
# 18203 1,098.000
# 18204 1,189.000
# 18205 1,228.000
#
# [18206 rows x 1 columns]

# %% [markdown]
# ### Menampilkan 10 record pertama dari attribute bertipe angka

# %%
show_angka = df.select_dtypes(include=np.number)
show_angka.head(10)
# Out:
#    Unnamed: 0      ID  Age  Overall  Potential   Special  \
# 0           0  158023   31       94         94 2,202.000
# 1           1   20801   33       94         94 2,228.000
# 2           2  190871   26       92         93 2,143.000
# 3           3  193080   27       91         93 1,471.000
# 4           4  192985   27       91         92 2,281.000
# 5           5  183277   27       91         91 2,142.000
# 6           6  177003   32       91         91 2,280.000
# 7           7  176580   31       91         91 2,346.000
# 8           8  155862   32       91         91 2,201.000
# 9           9  200389   25       90         93 1,331.000
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  ...  \
# 0                     5.000      4.000        4.000         10.000  ...
# 1                     5.000      4.000        5.000          7.000  ...
# 2                     5.000      5.000        5.000         10.000  ...
# ...

# %% [markdown]
# ### Menyimpan Dataset bertipe angka kedalam File CSV

# %%
df[['ID','Age','Overall','Potential','Special','International Reputation', 'Weak Foot','Skill Moves','Jersey Number','Penalties','Composure','Marking','StandingTackle','SlidingTackle','GKDiving','GKHandling','GKKicking','GKPositioning','GKReflexes']].to_csv("Hasil.csv")
